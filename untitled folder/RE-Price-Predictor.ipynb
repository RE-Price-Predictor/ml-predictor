# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import warnings

# %%
# Read Cali Income by Zip 
file_path = Path("Cali Incomes by Zip.csv")
df_cali_incomes = pd.read_csv(file_path)
# Display sample data
df_cali_incomes.head(10)
# Out:
#    Rank Median Household Income  Zip / Population    Zip Population  \
# 0  1247                 $42,500        95568 / 94  95568         94
# 1  1677                 $13,906        93528 / 79  93528         79
# 2  1340                 $39,375        95646 / 98  95646         98
# 3  1294                 $41,042        96076 / 88  96076         88
# 4  1315                 $40,341        94576 / 87  94576         87
# 5  1540                 $31,296        92266 / 62  92266         62
# 6  1582                 $28,897        95486 / 54  95486         54
# 7   373                 $80,729        92384 / 34  92384         34
# 8   149                $102,500        92364 / 30  92364         30
# 9  1639                 $24,009        93623 / 58  93623         58
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN

# %%
# Clean the data

df_cali_incomes1 = df_cali_incomes.loc[["Median Household Income", "Zip", "Population"]]
df_cali_incomes1.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Clean the data
# ----> 3 df_cali_incomes1 = df_cali_incomes.loc[["Median Household Income", "Zip", "Population"]]
#       4 df_cali_incomes1.head()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexing.py:1301, in _LocIndexer._getitem_axis(self, key, axis)
#    1298     if hasattr(key, "ndim") and key.ndim > 1:
#    1299         raise ValueError("Cannot index with multidimensional key")
# -> 1301     return self._getitem_iterable(key, axis=axis)
#    1303 # nested tuple slicing
# ...

# %%
# Read realtor data
file_path = Path("realtor-data.csv")
df_realtor = pd.read_csv(file_path)
# Display sample data
df_realtor.head(10)

# %%
# Clean the Realtor data

df_realtor = df_realtor.dropna()
display(df_realtor.head())

# %%
# join the realtor data with Cali incomes by zip based on zip code

joined_data_rows = pd.concat([df_realtor,df_cali_incomes], axis="rows", join="inner")
joined_data_rows
